# %% [markdown]
# # Link Lists
#
# In today's class, we're going to introduce the two varieties of linked lists:
# 1. Singly Linked Lists (uni-directional)
# 2. Doubly Linked Lists (bi-directional)

# %%
# How python does it

help ([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
mylist = []
# printing an empty list:
print(mylist)

mylist.append(0)
#printing a list with exactly one element:
print(mylist)

mylist.append(1)
#printing a list with more than 1 element
print(mylist)
# Out:
# []
# [0]
# [0, 1]

# %%
# From scratch implementation of Singly Linked List

class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self.__Node(value) #value is the incoming parameter
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            self.tail = new_node

    def insert(self, index, value):
        # Create new node with incoming value
        # Check if there is a head, if there is no head
        #     Make it so that my new node is now the head node
        #     also make it so that my new node is the tail node
        #otherwise:
        #     if the index I recieved is 0:
        #         replace the head reference to point to my new node
        #otherwise:
        #     initlaize a variable called current which starts by pointing at the head node
        #     initilize a variable called previous which starts by pointing a none
        #     initalize a variable called count which starts at 0
        #     loop while these two conditions are not met ->
        #         condition 1: there must be a next node to loop into
        #         condition 2: I ahve not yet found the target index
        #     these are the instructions taht happen every time I loop:
        #        1. I update previous to point to the same thing current is pointing to
        #        2. I update current to point tot the next node in my list
        #        3. I update count such that count is now equal to cout plus 1
        #When I exit the loop one of two conditions can be met:
        #    if count is equal to index: (this means I found my target index)
        #        update the previous node next ref to point to the new node
        #        Update new node next ref to point to current
        #    otherwise: (searched for target and never found it)
        #        execute the append operation

    def remove(self, value):
        if not self.head: #validate whether node is empty
           raise IndexError("List is empty") # raise an IndexError stating the "value is empty"
        else #else:
            current = self.head #states the current begining node
            previous = None
        
            #loop until target node is found
             #point previous value to next node after target value and make it the next value
            
            
            
            #while current.next: #as long as there is a next node, we are going to loop 
                #current = current.next
        

    def __str__(self): #rendering our list as a string
        out = "[" #out string with an opening bracket
        current = self.head #puts to one node, if true
        if current:
            out += "%s" % repr(current.data) #loop as many times as there are data
            while current.next: #as long as there is a next node, we are going to loop 
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]" # completes the square bracket
        return out

# %%
sll = SinglyLinkedList()

# When the list is empty:
print(sll)

# when the list contains exactly one element
sll.append(0)
print(sll)

# when the list contians more than one element
sll.append(1)
print(sll)
# Out:
# []
# [0]
# [0, 1]

# %%
def insert(self, index, object, /)
      Insert object before index.

 remove(self, value, /)
       Remove first occurrence of value.
       
       Raises ValueError if the value is not present.

# %%
# With python lists
newlist = []

# inserting at index 1000 on an empty list
newlist.insert(1000, "A")

print(newlist)

#replacing the head node

newlist.insert (0,"Z")
print(newlist)

#when the privided index is exactly equal to 0, we are replacing the head node with insert
# inserting anywhere between the head and tail
newlist.insert(1, 1)
print(newlist)
# Out:
# ['A']
# ['Z', 'A']
# ['Z', 1, 'A']
