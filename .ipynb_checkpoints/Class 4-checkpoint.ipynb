# %% [markdown]
# #Doubly Linked List
#
# A Doubly Linked List is also known as a bi-directional list. It is comprised of `nodes` that keep and maintain a reference to the `previous` node in the collection, as well as the `next` node in the collection.

# %%
# From scratch implementation of Doubly Linked Lists

class DoublyLinkedList:
    class __Node:
        def __init__(self, data):
            self.prev = None
            self.next = None
            self.data = data

    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = self. __Node(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node

        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def insert(self, index, value):
        #this inserts a new node with the given value BEFORE the target index
        #Note: There are some additional considerations for the combinations of "index" and the state of our list.
        pass

    def remove(self, value):
        #this removes the *first* instance of the given value
        pass
        
    def index(self, value):
        #this returns the *first* instance of the given value
        pass

    def __get__(self, index):#this method allows you to use square bracket notation to retrieve a value at the target index (IE dll[5])
        # check to see if list is empty
        # if list is empty
            # raise an IndexError
        # otherwise:
        # if list is not empty, then 
            # set head and tail to new node
            # create a variable current and equal it the head
            # create a count variable and set it to 0
            #create a variable value and equal it to index
            
        # start a loop to find target index
        # while current is not none
            # add a count of 1 to each node it encounters
            # set current to the next node until it reaches the target index
        # return value of target index 
        
        
        pass

    def __set__(self, index, value):
        #this method allows you to use square bracket notation to insert a node into the list (IE dll[5] = "A")
        pass

    def __len__(self):
        #this returns the number of nodes in our list
        count = 0 #sets the count to 0
        current = self.head #sets the current to the head of the list puts to 1 node (self.head is a local reference)
        while current: # starts the loop, if current is not none
            count += 1 # adds a count of 1 to each node it encounters
            current = current.next #update current to the next node until there is no node
            return count # when list is exausted, return the count
        pass

    def __boo__(self):
        #this will help evaluate our list with "if" and "if not"
        return self.head != None # != means not equal to
        
        
    def inverted(self):
    # this method allows us to print (or return a sring) of our lsit, but in inverted order
        pass

    def __str__(self):
        #remeber, this method must return a string
        out = "["
        current = self.head
        if current:
            out += "%s" % repr(current.data)
            while current.next:
                current = current.next
                out += ", %s" % repr(current.data)
        out += "]"
        return out

# %%
# Comparing python3 list to our DLL implementation

pylist = []
dll = DoublyLinkedList()

# Empty list:
print("Empty python list: %s" % pylist)
print("Empty DLL: %s" % dll)

#Our lists with exactly one element:
pylist.append(0)
dll.append(0)
print("Python list with one element %s" % pylist)
print("DLL with one element: %s" % dll)

#Our lists with more than one element:
pylist.append(1)
dll.append(1)
print("Python list with one element %s" % len(pylist))
print("DLL with one element: %s" % len(dll))
# Out:
# Empty python list: []
# Empty DLL: []
# Python list with one element [0]
# DLL with one element: [0]
# Python list with one element 2
# DLL with one element: 1
